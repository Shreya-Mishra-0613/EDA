# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data\crop_yield.csv")

# %% [markdown]
# ### understanding data

# %%
data.shape #Size of data
# Out:
# (19689, 10)

# %%
data.head() #How data looks like
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
data.tail()
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide     Yield
# 19684        2000           1498.0    395200.00    1160.00  0.500000
# 19685        3000           1498.0     98800.00     290.00  3.000000
# 19686      440900           1356.2  29586735.11   96373.73  1.285000
# 19687        5488           1356.2  26242746.82   85481.26  0.016667
# 19688      392160           1356.2  22778368.48   74196.64  1.261818

# %%
data.sample(5)
# Out:
#             Crop  Crop_Year       Season         State      Area  Production  \
# 3379     Sesamum       2011  Kharif              Assam   11801.0        7957
# 7530      Potato       2001  Whole Year   Chhattisgarh    9315.0       64152
# 4912    Coconut        2016  Whole Year            Goa   25913.0   132160000
# 13830  Groundnut       2014  Kharif        Maharashtra  243800.0      252900
# 1521       Wheat       2003  Rabi          West Bengal  425721.0      985686
#
#        Annual_Rainfall   Fertilizer  Pesticide        Yield
# 3379            1743.4   1976903.52    3894.33     0.594444
# 7530            1550.0    951340.95    2421.90     6.849375
# 4912            3266.9   3971167.25    9069.55  5087.315000
# 13830           1001.6  36804048.00   80454.00     0.643636
# 1521            1526.7  42137864.58  102173.04     2.194444

# %%
data.info() #dtype of columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  object
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  object
#  3   State            19689 non-null  object
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
#area can be converted to int

# %%
data.isnull().sum() #missing values
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
data.describe() #Mathematical data
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# 75%    1.000385e+07  2.004170e+04      2.388889
# max    4.835407e+09  1.575051e+07  21105.000000

# %%
data.duplicated().sum() #check duplicate values
# Out:
# np.int64(0)

# %%
data.columns #column names
# Out:
# Index(['Crop', 'Crop_Year', 'Season', 'State', 'Area', 'Production',
#        'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Yield'],
#       dtype='object')

# %%
data.nunique() #Unique values in each Column
# Out:
# Crop                  55
# Crop_Year             24
# Season                 6
# State                 30
# Area               13644
# Production         14016
# Annual_Rainfall      634
# Fertilizer         18598
# Pesticide          17405
# Yield              13551
# dtype: int64

# %%
data["State"].unique()
# Out:
# array(['Assam', 'Karnataka', 'Kerala', 'Meghalaya', 'West Bengal',
#        'Puducherry', 'Goa', 'Andhra Pradesh', 'Tamil Nadu', 'Odisha',
#        'Bihar', 'Gujarat', 'Madhya Pradesh', 'Maharashtra', 'Mizoram',
#        'Punjab', 'Uttar Pradesh', 'Haryana', 'Himachal Pradesh',
#        'Tripura', 'Nagaland', 'Chhattisgarh', 'Uttarakhand', 'Jharkhand',
#        'Delhi', 'Manipur', 'Jammu and Kashmir', 'Telangana',
#        'Arunachal Pradesh', 'Sikkim'], dtype=object)

# %%
data["Season"].unique()
# Out:
# array(['Whole Year ', 'Kharif     ', 'Rabi       ', 'Autumn     ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
data["Crop_Year"].unique()
# Out:
# array([1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020])

# %%
data["Crop"].unique()
# Out:
# array(['Arecanut', 'Arhar/Tur', 'Castor seed', 'Coconut ', 'Cotton(lint)',
#        'Dry chillies', 'Gram', 'Jute', 'Linseed', 'Maize', 'Mesta',
#        'Niger seed', 'Onion', 'Other  Rabi pulses', 'Potato',
#        'Rapeseed &Mustard', 'Rice', 'Sesamum', 'Small millets',
#        'Sugarcane', 'Sweet potato', 'Tapioca', 'Tobacco', 'Turmeric',
#        'Wheat', 'Bajra', 'Black pepper', 'Cardamom', 'Coriander',
#        'Garlic', 'Ginger', 'Groundnut', 'Horse-gram', 'Jowar', 'Ragi',
#        'Cashewnut', 'Banana', 'Soyabean', 'Barley', 'Khesari', 'Masoor',
#        'Moong(Green Gram)', 'Other Kharif pulses', 'Safflower',
#        'Sannhamp', 'Sunflower', 'Urad', 'Peas & beans (Pulses)',
#        'other oilseeds', 'Other Cereals', 'Cowpea(Lobia)',
#        'Oilseeds total', 'Guar seed', 'Other Summer Pulses', 'Moth'],
#       dtype=object)

# %%
data.select_dtypes(include=['float64','int64']).corr() #correlation between columns
# Out:
#                  Crop_Year      Area  Production  Annual_Rainfall  Fertilizer  \
# Crop_Year         1.000000 -0.035686    0.003366        -0.011187    0.011169
# Area             -0.035686  1.000000    0.037441        -0.106054    0.973255
# Production        0.003366  0.037441    1.000000         0.029879    0.039799
# Annual_Rainfall  -0.011187 -0.106054    0.029879         1.000000   -0.109734
# Fertilizer        0.011169  0.973255    0.039799        -0.109734    1.000000
# Pesticide        -0.004657  0.973479    0.035171        -0.097657    0.954991
# Yield             0.002539  0.001858    0.570809         0.020761    0.002862
#
#                  Pesticide     Yield
# Crop_Year        -0.004657  0.002539
# Area              0.973479  0.001858
# Production        0.035171  0.570809
# Annual_Rainfall  -0.097657  0.020761
# Fertilizer        0.954991  0.002862
# Pesticide         1.000000  0.001782
# Yield             0.001782  1.000000

# %%
sns.heatmap(data.select_dtypes(include=['float64','int64']).corr(), annot=True)
# Out:
# <Axes: >

# %%
data.select_dtypes(include=['float64','int64']).corr()['Yield']
# Out:
# Crop_Year          0.002539
# Area               0.001858
# Production         0.570809
# Annual_Rainfall    0.020761
# Fertilizer         0.002862
# Pesticide          0.001782
# Yield              1.000000
# Name: Yield, dtype: float64

# %%
###univariate analysis

# %%
data.sample(10)
# Out:
#                      Crop  Crop_Year       Season              State     Area  \
# 10230           Groundnut       2007  Kharif                 Haryana   1314.0
# 13795       Small millets       2014  Kharif        Himachal Pradesh   4122.0
# 5238                 Rice       2017  Winter               Meghalaya  63883.0
# 16640                Urad       2018  Rabi               West Bengal   8186.0
# 11106        Dry chillies       2009  Kharif        Himachal Pradesh    603.0
# 18264        Cotton(lint)       2017  Kharif       Jammu and Kashmir      5.0
# 16498  Other  Rabi pulses       2018  Rabi                   Tripura    857.0
# 12685              Potato       2012  Kharif        Himachal Pradesh   6404.0
# 18391            Turmeric       2019  Kharif       Jammu and Kashmir      4.0
# 11790                Urad       2010  Kharif                  Punjab   2800.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide      Yield
# 10230        1000            443.8    175287.60     210.24   0.598333
# 13795        2987           1019.9    622257.12    1360.26   0.738571
# 5238       162272           4472.3  10057739.52   24275.54   2.360000
# 16640        8056           2012.6   1327769.20    2865.10   0.727000
# 11106         318            969.9     93959.46     102.51   0.545000
# 18264           3           1279.1       787.20       1.90   0.520000
# 16498         724           2169.1    139005.40     299.95   0.857500
# 12685       65510           1035.0    965723.20    1985.24  10.782000
# 18391           4           1324.1       687.04       1.48   1.000000
# 11790        1600            392.7    465108.00     672.00   0.734000

# %%
##categorical data

# %%
#countplot

# %%
plt.figure(figsize=(12, 20))
sns.countplot(data['Crop']) 
# data['Crop'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='count', ylabel='Crop'>

# %%
sns.countplot(data['Season'])
# Out:
# <Axes: xlabel='count', ylabel='Season'>

# %%
# sns.countplot(data['State'])
data['State'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='State'>

# %%
#PieChart

# %%
data['Crop_Year'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['Season'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
##numerical data

# %%
#Histogram

# %%
plt.hist(data['Annual_Rainfall'], bins=50)
# Out:
# (array([ 503.,  508.,  841., 1129., 1643., 2023., 2051., 1827., 2137.,
#         1245., 1032.,  800.,  356.,  498.,  400.,  292.,  284.,  336.,
#          250.,  126.,  169.,  302.,  138.,   75.,  115.,   90.,   35.,
#            7.,  174.,    0.,   31.,   30.,   38.,   48.,    0.,   49.,
#            0.,    0.,    0.,    0.,    0.,    0.,   34.,    0.,    0.,
#            0.,    0.,   48.,    0.,   25.]),
#  array([ 301.3  ,  426.328,  551.356,  676.384,  801.412,  926.44 ,
#         1051.468, 1176.496, 1301.524, 1426.552, 1551.58 , 1676.608,
#         1801.636, 1926.664, 2051.692, 2176.72 , 2301.748, 2426.776,
#         2551.804, 2676.832, 2801.86 , 2926.888, 3051.916, 3176.944,
#         3301.972, 3427.   , 3552.028, 3677.056, 3802.084, 3927.112,
#         4052.14 , 4177.168, 4302.196, 4427.224, 4552.252, 4677.28 ,
#         4802.308, 4927.336, 5052.364, 5177.392, 5302.42 , 5427.448,
#         5552.476, 5677.504, 5802.532, 5927.56 , 6052.588, 6177.616,
#         6302.644, 6427.672, 6552.7  ]),
#  <BarContainer object of 50 artists>)

# %%
#Distplot (improved histogram)

# %%
sns.displot(data['Annual_Rainfall'], kde=True, bins=50) #kde, pdf, skewness

# %%
data['Annual_Rainfall'].skew()
# Out:
# np.float64(2.1317850114644354)

# %%
sns.distplot(data['Yield'])
# Out:
# C:\Users\SHREYA MISHRA\AppData\Local\Temp\ipykernel_9540\3689484916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Yield'])
# <Axes: xlabel='Yield', ylabel='Density'>

# %%
sns.distplot(data['Area'])
# Out:
# C:\Users\SHREYA MISHRA\AppData\Local\Temp\ipykernel_9540\3737716526.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Area'])
# <Axes: xlabel='Area', ylabel='Density'>

# %%
sns.distplot(data['Production'])
# Out:
# C:\Users\SHREYA MISHRA\AppData\Local\Temp\ipykernel_9540\3991622870.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Production'])
# <Axes: xlabel='Production', ylabel='Density'>

# %%
#Boxplot

# %%
sns.boxplot(data['Annual_Rainfall']) #InterQuartile Range(IQR)
# Out:
# <Axes: ylabel='Annual_Rainfall'>

# %%
sns.boxplot(data['Area'])
# Out:
# <Axes: ylabel='Area'>

# %%
sns.boxplot(data['Fertilizer'])
# Out:
# <Axes: ylabel='Fertilizer'>

# %%
###bivariate and multivariate analysis

# %%
data.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
##Scatterplot (Numerical-Numerical)

# %%
sns.scatterplot(x=data['Area'], y=data['Pesticide'], hue=data['Season'])
# Out:
# <Axes: xlabel='Area', ylabel='Pesticide'>

# %%
sns.scatterplot(x=data['Pesticide'], y=data['Fertilizer'], hue=data['Season'])
# Out:
# <Axes: xlabel='Pesticide', ylabel='Fertilizer'>

# %%
sns.scatterplot(x=data['Crop_Year'], y=data['Yield'], hue=data['Season'])
# Out:
# <Axes: xlabel='Crop_Year', ylabel='Yield'>

# %%
##Bar Plot(Numerical - Categorical)

# %%
plt.xticks(rotation=90)
sns.barplot(x=data['State'], y=data['Yield'], errorbar=('ci', 90)) #confidence interval
# Out:
# <Axes: xlabel='State', ylabel='Yield'>

# %%
plt.xticks(rotation=90)
sns.barplot(x=data['State'], y=data['Production'])
# Out:
# <Axes: xlabel='State', ylabel='Production'>

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sns.barplot(x=data['Crop'], y=data['Yield'])
# Out:
# <Axes: xlabel='Crop', ylabel='Yield'>

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
sns.barplot(x=data['Crop'], y=data['Annual_Rainfall'])
# Out:
# <Axes: xlabel='Crop', ylabel='Annual_Rainfall'>

# %%
sns.barplot(x=data['Season'], y=data['Yield'])
# Out:
# <Axes: xlabel='Season', ylabel='Yield'>

# %%
#Box Plot(Numerical- Categorical)

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.boxplot(x=data['State'], y=data['Annual_Rainfall'])
# Out:
# <Axes: xlabel='State', ylabel='Annual_Rainfall'>

# %%
#HeatMap and clustermap(C-C)

# %%
pd.crosstab(data['State'], data['Crop'])
# Out:
# Crop               Arecanut  Arhar/Tur  Bajra  Banana  Barley  Black pepper  \
# State
# Andhra Pradesh           18         41     45      18       0             2
# Arunachal Pradesh         0          4      0       0       0             0
# Assam                    22         23      0      21       0            13
# Bihar                     0         23     23      10      22             0
# Chhattisgarh              0         20     39       0      20             0
# Delhi                     0          4     22       0      22             0
# Goa                      13          0      0      13       0            17
# Gujarat                   0         23     46      22       0             0
# Haryana                   0         22     23       2      23             0
# Himachal Pradesh          0         20     20       0      22             0
# Jammu and Kashmir         0          2     24       0      35             0
# Jharkhand                 0         20      3       0       2             0
# Karnataka                21         23     55      12       0            23
# Kerala                   23          8      0      22       0            23
# Madhya Pradesh            0         23     23      16      22             0
# Maharashtra               0         23     23       1       0             0
# Manipur                   0         12      0      26       0             0
# Meghalaya                21         22      0      21       0            13
# Mizoram                   0         23      0       0       0             0
# Nagaland                  0         21     19       0      16             0
# Odisha                    0         12      7       0       0             0
# Puducherry               17          0     32      21       0            18
# Punjab                    0         23     20       0      23             0
# Sikkim                    0          0      0       0      23             0
# Tamil Nadu               16         21     28      19       0            17
# Telangana                 0         14     14       7       0             0
# Tripura                   0         17      0       0       0             0
# Uttar Pradesh             0         20     23      14      23             0
# Uttarakhand               0         21     12       0      21             0
# West Bengal              11         23     23       0      23             0
#
# Crop               Cardamom  Cashewnut  Castor seed  Coconut   ...  Soyabean  \
# State                                                          ...
# Andhra Pradesh            0         19           30        19  ...        25
# Arunachal Pradesh         0          0            0         0  ...         6
# Assam                     0          0           23        22  ...         0
# Bihar                     0          0           18         0  ...         1
# Chhattisgarh              0          0           20         7  ...        20
# Delhi                     0          0            0         0  ...         0
# Goa                       0         17            0        17  ...         0
# Gujarat                   0          0           24         0  ...        10
# Haryana                   0          0           14         0  ...         2
# Himachal Pradesh          0          0            0         0  ...        20
# Jammu and Kashmir         0          0            0         0  ...         0
# Jharkhand                 0          0            3         0  ...         3
# Karnataka                22         12           22        22  ...        22
# Kerala                   21         23            0        23  ...         4
# Madhya Pradesh            0          1           18         0  ...        23
# Maharashtra               0          0           20         0  ...        22
# Manipur                   0          6            0         0  ...        21
# Meghalaya                 0         12           22         0  ...        20
# Mizoram                   0          0            0         1  ...        18
# Nagaland                  3          0           13         0  ...        21
# Odisha                    0          0           14         0  ...         1
# Puducherry                0         18            0        20  ...         0
# Punjab                    0          0            0         0  ...         0
# Sikkim                    0          0            0         0  ...        23
# Tamil Nadu               18         19           21        16  ...         1
# Telangana                 0          7           14         2  ...        11
# Tripura                   0          0            0         0  ...         8
# Uttar Pradesh             0          0            4         0  ...        23
# Uttarakhand               0          0            0         0  ...        21
# West Bengal              10          0           20        23  ...        23
#
# Crop               Sugarcane  Sunflower  Sweet potato  Tapioca  Tobacco  \
# State
# Andhra Pradesh            23         35            27       26       32
# Arunachal Pradesh         23          6             0        0        0
# Assam                     23          0            23       22       23
# Bihar                     21         23            12        0       21
# Chhattisgarh              21         21            20        0       19
# Delhi                     16          0             0        0        0
# Goa                       22          0             4        0        0
# Gujarat                   23          0             0        0       34
# Haryana                   23         22            14        0        2
# Himachal Pradesh          19          0             1        0        5
# Jammu and Kashmir         16          0             0        0       13
# Jharkhand                 11          6             0        0        0
# Karnataka                 21         66            20       20       19
# Kerala                    22          1            20       23       21
# Madhya Pradesh            22         21            19        0       10
# Maharashtra               23         65             0        0        7
# Manipur                   25          0             9        4        0
# Meghalaya                 23          0            23       22       23
# Mizoram                   22          2             0       20       22
# Nagaland                  23         41             9       13        0
# Odisha                    23         13             9        0        7
# Puducherry                22          4            18       32        1
# Punjab                    19          6             0        0        0
# Sikkim                     0          0             0        0        0
# Tamil Nadu                22         29            19       19       17
# Telangana                  7         14            10        0       14
# Tripura                   22          0             0        0        0
# Uttar Pradesh             24         22            16        0       34
# Uttarakhand               21         21             0        0       19
# West Bengal               23         23             0        0       21
#
# Crop               Turmeric  Urad  Wheat  other oilseeds
# State
# Andhra Pradesh            0    46     24              10
# Arunachal Pradesh        22     8     23               4
# Assam                    23    19     23               0
# Bihar                    15    22     23               0
# Chhattisgarh             20    40     20               0
# Delhi                     0     0     22               0
# Goa                       0     0      0               3
# Gujarat                   0    33     23               2
# Haryana                  12    22     23               9
# Himachal Pradesh         17    20     22               0
# Jammu and Kashmir        19    21     22              22
# Jharkhand                 0     5     19               0
# Karnataka                23    47     23               0
# Kerala                   22     3      7               1
# Madhya Pradesh           19    33     23               0
# Maharashtra               0    23     23               9
# Manipur                  22    11     11               0
# Meghalaya                21     0     22               0
# Mizoram                   0     8      4              11
# Nagaland                  2    16     21               5
# Odisha                    7    60     23               0
# Puducherry               15    47      0               0
# Punjab                    0    21     23               1
# Sikkim                    0    23     23               5
# Tamil Nadu               19    29      0               0
# Telangana                 8    14      9               3
# Tripura                   0    34     22               3
# Uttar Pradesh            21    40     23               0
# Uttarakhand              18    42     21              38
# West Bengal              12    46     23               0
#
# [30 rows x 55 columns]

# %%
plt.figure(figsize=(20,12))
sns.heatmap(pd.crosstab(data['State'], data['Crop']),annot=True)
# Out:
# <Axes: xlabel='Crop', ylabel='State'>

# %%
sns.clustermap(pd.crosstab(data['Crop'],data['Crop_Year']), annot=True)

# %%
#Pairplot (collection of scatterplots)

# %%
# sns.pairplot(data.sample(1000))

# %%
#Lineplot(n-n)

# %%
data.groupby('Crop_Year').sum().reset_index()
# Out:
#     Crop_Year                                               Crop  \
# 0        1997  ArecanutArhar/TurCastor seedCoconut Cotton(lin...
# 1        1998  ArecanutBajraBlack pepperCorianderCotton(lint)...
# 2        1999  ArecanutArhar/TurBananaCastor seedCoconut Cott...
# 3        2000  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 4        2001  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 5        2002  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 6        2003  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 7        2004  ArecanutArhar/TurBajraBajraBajraBananaBlack pe...
# 8        2005  ArecanutArhar/TurBajraBajraBananaCashewnutCast...
# 9        2006  ArecanutArecanutBananaBlack pepperCotton(lint)...
# 10       2007  ArecanutBajraBananaBlack pepperCoconut Coriand...
# 11       2008  ArecanutBajraBajraBananaBlack pepperCashewnutC...
# 12       2009  ArecanutBajraBajraBananaBlack pepperCashewnutC...
# 13       2010  ArecanutBajraBajraBananaBlack pepperCashewnutC...
# 14       2011  ArecanutBajraBajraBananaBlack pepperCashewnutC...
# 15       2012  ArecanutArhar/TurBajraBajraCashewnutCastor see...
# 16       2013  ArecanutArhar/TurArhar/TurBajraBajraBananaBlac...
# 17       2014  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 18       2015  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 19       2016  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 20       2017  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 21       2018  ArecanutArhar/TurArhar/TurBajraBajraBananaCash...
# 22       2019  ArecanutArhar/TurArhar/TurBajraBajraBananaBlac...
# 23       2020  Arhar/TurBarleyGarlicGramGroundnutHorse-gramMa...
#
#                                                Season  \
# 0   Whole Year Kharif     Kharif     Whole Year Kh...
# 1   Kharif     Kharif     Kharif     Kharif     Su...
# 2   Whole Year Kharif     Whole Year Kharif     Wh...
# 3   Whole Year Kharif     Rabi       Kharif     Ra...
# 4   Whole Year Kharif     Rabi       Kharif     Ra...
# 5   Whole Year Kharif     Rabi       Kharif     Ra...
# 6   Whole Year Kharif     Rabi       Kharif     Ra...
# 7   Whole Year Kharif     Kharif     Rabi       Su...
# 8   Whole Year Kharif     Kharif     Rabi       Wh...
# 9   Kharif     Whole Year Kharif     Kharif     Su...
# 10  Kharif     Kharif     Kharif     Kharif     Wh...
# 11  Kharif     Kharif     Summer     Kharif     Kh...
# 12  Kharif     Kharif     Summer     Kharif     Kh...
# 13  Kharif     Kharif     Summer     Kharif     Kh...
# 14  Kharif     Kharif     Summer     Kharif     Kh...
# 15  Kharif     Kharif     Kharif     Rabi       Kh...
# 16  Kharif     Kharif     Rabi       Kharif     Ra...
# 17  Kharif     Kharif     Rabi       Kharif     Ra...
# 18  Kharif     Kharif     Rabi       Kharif     Ra...
# 19  Kharif     Kharif     Rabi       Kharif     Ra...
# 20  Kharif     Kharif     Rabi       Kharif     Ra...
# 21  Kharif     Kharif     Rabi       Kharif     Ra...
# 22  Kharif     Kharif     Rabi       Kharif     Ra...
# 23  Kharif     Rabi       Whole Year Rabi       Kh...
#
#                                                 State          Area  \
# 0   AssamAssamAssamAssamAssamAssamAssamAssamAssamA...  1.660686e+08
# 1   PuducherryPuducherryPuducherryPuducherryPuduch...  1.501238e+08
# 2   AssamAssamAssamAssamAssamAssamAssamAssamAssamA...  1.470574e+08
# 3   Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.475277e+08
# 4   Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.456943e+08
# 5   Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.427858e+08
# 6   Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.496968e+08
# 7   KarnatakaKarnatakaKarnatakaKarnatakaKarnatakaK...  1.480245e+08
# 8   Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.479183e+08
# 9   PuducherryPuducherryPuducherryPuducherryPuduch...  1.522491e+08
# 10  PuducherryPuducherryPuducherryPuducherryPuduch...  1.524861e+08
# 11  PuducherryPuducherryPuducherryPuducherryPuduch...  1.509647e+08
# 12  PuducherryPuducherryPuducherryPuducherryPuduch...  1.486685e+08
# 13  PuducherryPuducherryPuducherryPuducherryPuduch...  1.581894e+08
# 14  PuducherryPuducherryPuducherryPuducherryPuduch...  1.544121e+08
# 15  Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.585360e+08
# 16  Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.575644e+08
# 17  Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.544366e+08
# 18  Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.559359e+08
# 19  Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.603649e+08
# 20  Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.625001e+08
# 21  Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.613595e+08
# 22  Andhra PradeshAndhra PradeshAndhra PradeshAndh...  1.690919e+08
# 23  UttarakhandUttarakhandUttarakhandUttarakhandUt...  9.179160e+05
#
#      Production  Annual_Rainfall    Fertilizer     Pesticide          Yield
# 0    6087009873     6.542691e+05  1.580475e+10  5.148126e+07   26187.756592
# 1    7868086697     1.138474e+06  1.483223e+10  4.353590e+07   36136.246483
# 2    8550025528     1.033857e+06  1.560720e+10  3.970550e+07   50013.419395
# 3    9562470060     1.119624e+06  1.448280e+10  3.835721e+07   58342.279827
# 4    9314563490     1.055077e+06  1.487976e+10  3.788053e+07   56581.195447
# 5   12409349456     1.040622e+06  1.351753e+10  3.569644e+07   65734.814831
# 6   12313711969     1.135610e+06  1.481699e+10  3.592724e+07   67039.368873
# 7   13817065380     1.141189e+06  1.603697e+10  3.108514e+07   63905.917053
# 8   14951210018     1.185828e+06  1.773836e+10  3.106285e+07   70140.586280
# 9   15702675600     1.120933e+06  1.944373e+10  3.349481e+07   63765.246251
# 10  14471191552     1.282614e+06  2.034164e+10  2.439777e+07   63548.814332
# 11  16165771744     1.160613e+06  2.159398e+10  1.358682e+07   72534.452889
# 12  16604163998     1.022008e+06  2.316552e+10  2.527364e+07   74346.506928
# 13  11952654246     1.260904e+06  2.627684e+10  3.796545e+07   62000.578526
# 14  19260119964     1.253200e+06  2.586711e+10  5.095598e+07   76228.823500
# 15  13030757834     1.128220e+06  2.390723e+10  4.914617e+07   68448.386183
# 16  17040254359     1.400296e+06  2.276649e+10  4.254240e+07   92591.163834
# 17  17729042495     1.246912e+06  2.331374e+10  5.096406e+07  103400.057624
# 18  18329298670     1.353716e+06  2.462384e+10  5.145886e+07   82077.740509
# 19  16357287264     1.554648e+06  2.457592e+10  5.612772e+07   80860.122961
# 20  15873843241     1.596034e+06  2.558402e+10  6.175004e+07   79981.909996
# 21  17933914698     1.734000e+06  2.617252e+10  5.647583e+07   79994.686005
# 22  18272602364     1.640698e+06  2.904323e+10  6.256401e+07   80190.867894
# 23     10177226     4.861607e+04  1.777177e+08  3.396289e+05     163.543553

# %%
crop=data.groupby('Crop_Year').sum().reset_index()

# %%
sns.lineplot(x=crop['Crop_Year'], y=crop['Fertilizer'])
# Out:
# <Axes: xlabel='Crop_Year', ylabel='Fertilizer'>

# %%
sns.lineplot(x=crop['Crop_Year'], y=crop['Pesticide'])
# Out:
# <Axes: xlabel='Crop_Year', ylabel='Pesticide'>

# %%
sns.lineplot(x=crop['Crop_Year'], y=crop['Annual_Rainfall'])
# Out:
# <Axes: xlabel='Crop_Year', ylabel='Annual_Rainfall'>

# %%
sns.lineplot(x=crop['Crop_Year'], y=crop['Production'])
# Out:
# <Axes: xlabel='Crop_Year', ylabel='Production'>

# %%
sns.lineplot(x=crop['Crop_Year'], y=crop['Area'])
# Out:
# <Axes: xlabel='Crop_Year', ylabel='Area'>

# %%
sns.lineplot(x=crop['Crop_Year'], y=crop['Yield'])
# Out:
# <Axes: xlabel='Crop_Year', ylabel='Yield'>

# %%
sns.barplot(crop['Annual_Rainfall'])
# Out:
# <Axes: ylabel='Annual_Rainfall'>
